# %%
#!/usr/bin/python
# e begoli, python connector for mysql
# import MySQL module
import MySQLdb

import vincent 
from vincent import AxisProperties, PropertySet, ValueRef
import random

import pandas as pd
vincent.initialize_notebook()
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>

# %%
cats = {
    "swim_stat": 9,
    "fly_stat": 10,
    "run_stat": 11,
    "power_stat": 12,
    "stamina_stat": 15,
    "hat": 16,
    "intellegence": 17,
    "trips": 18,
#     "luck": 19
}

filtered_cats = {
    "swim_stat": 9,
    "fly_stat": 10,
    "run_stat": 11,
    "power_stat": 12
}

courses = [
    "crab_pool",
    "stump_valley",
    "mushroom_forest",
    "block_canyon",
    "aquamarine",
    "topaz",
    "peridot",
    "garnet",
    "onyx",
    "diamond",
    "overall"
]

prediction_names = [
    "filtered_stochastic",
    "unfiltered_stochastic",
    "filtered_batch",
    "unfiltered_batch",
    "filtered_stochastic_final",
    "unfiltered_stochastic_final",
    "filtered_batch_final",
    "unfiltered_batch_final",
    "filtered_stochastic_power",
    "unfiltered_stochastic_power",
    "filtered_batch_power",
    "unfiltered_batch_power",
    "filtered_stochastic_fina_power",
    "unfiltered_stochasticl_final_power",
    "filtered_batch_final_power",
    "unfiltered_batch_final_power",
    "average_prediction"
]

# %%
# connect
db = MySQLdb.connect(host="localhost", user="root", passwd="", db="Chao")

# create a database cursor
cursor = db.cursor()

# execute SQL select statement
cursor.execute("SELECT * FROM Chao")

# get the number of rows in the resultset
numchao = int(cursor.rowcount)

chao_map = {}
for x in range(0,numchao):
    row = cursor.fetchone()
    # fill map {chao_name: "swim": swim_stat, "fly": fly_stat ... up to luck}
    stat_map = {}
    for cat in cats.keys():
        stat_map[cat] = int(row[cats[cat]])
    chao_map[row[1]] = stat_map
print chao_map.get('peaches')
# Out:
# {'swim_stat': 805, 'fly_stat': 728, 'power_stat': 383, 'stamina_stat': 159, 'trips': 0, 'run_stat': 1235, 'hat': 0, 'intellegence': 0}

# %%
max_stat_map = {}
for cat in cats.keys():

    # execute SQL select statement
    cursor.execute("SELECT MAX("+cat+") FROM Chao")
    
    row = cursor.fetchone()
    max_stat_map[cat] = float(row[0])
    if max_stat_map[cat] < 1:
        max_stat_map[cat] = 1.0
print max_stat_map
# Out:
# {'swim_stat': 2981.0, 'fly_stat': 3015.0, 'power_stat': 3016.0, 'stamina_stat': 912.0, 'trips': 1.0, 'run_stat': 3031.0, 'hat': 1.0, 'intellegence': 1.0}

# %%
filtered = False
raw = False
group_by = 16

def plot_results(data, course, names):
    # plot results
    print course
    stacked = vincent.StackedArea(data, iter_idx='index')
    stacked.axis_titles(x='Index', y='Data Value')
    stacked.legend(title='Categories')
    stacked.colors(brew='Set3')
    stacked.display()
    df = pd.DataFrame(data, index=names)
    del df['index']
    for i in [i*group_by for i in range(len(df.index) / group_by)]:
        print course
        grouped = vincent.GroupedBar(df[len(df.index)-i-group_by:len(df.index)-i])
        grouped.colors(brew='Set3')
        grouped.axis_titles(x='Dataset', y='Value')
        grouped.legend(title=course)
        grouped.width = 700
        grouped.height = 150
        grouped.display()


for course in courses:
    data_all = {}
    data = {}
    names = []

    # execute SQL select statement
    cursor.execute("SELECT * FROM results WHERE course = '"+course+"';")

    # get the number of rows in the resultset
    numrows = int(cursor.rowcount)

    prev_score = 200
    index = 0
    index_all = 0
    for x in range(0,numrows):
        index += 1
        index_all += 1
        row = cursor.fetchone()
        curr_score = row[3]
        chao_name = row[2]
        # check if done for group and can plot
        if prev_score < curr_score:
#             if data_all == {}:
#                 data_all = data.copy()
#             else:
#                 data_all = { k: [x + y for x, y in zip(data[k], data_all[k])] for k in data.keys() } # sum value lists from old and new map
            data["index"] = range(0, index-1, 1)
            plot_results(data, course, names)
            #reset
            data = {}
            names = []
            index = 1
        # get results (fill a map with the results data = {"swim": [last_stat...first_stat]})
        names = [chao_name] + names
        for cat in cats.keys():
            if (cat in filtered_cats.keys() and filtered) or not filtered:
                if raw:
                    if data.has_key(cat):
                        data[cat] = [int(chao_map[chao_name][cat])] + data[cat]
                    else:
                        data[cat] = [int(chao_map[chao_name][cat])]
                else:
                    if data.has_key(cat):
                        data[cat] = [round(int(chao_map[chao_name][cat])/max_stat_map[cat],2)] + data[cat]
                    else:
                        data[cat] = [round(int(chao_map[chao_name][cat])/max_stat_map[cat],2)]


        # update
        prev_score = curr_score
        
#     data_all = { k: [x + y for x, y in zip(data[k], data_all[k])] for k in data.keys() }
    data["index"] = range(0, index, 1)
#     data_all["index"] = range(0, index_all, 1)
#     for key in data_all.keys():
#         print len(data_all[key])
#         print data_all[key]
    plot_results(data, course, names)
#     plot_results(data_all, course)
# Out:
# crab_pool
# <div id="visbc8a915351274cd9b8b904f9320a7d56"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        
": 0.0}, {"col": "fly_stat", "idx": "gills", "val": 0.25}, {"col": "hat", "idx": "gills", "val": 0.0}, {"col": "intellegence", "idx": "gills", "val": 0.0}, {"col": "power_stat", "idx": "gills", "val": 0.02}, {"col": "run_stat", "idx": "gills", "val": 0.03}, {"col": "stamina_stat", "idx": "gills", "val": 0.68}, {"col": "swim_stat", "idx": "gills", "val": 0.48}, {"col": "trips", "idx": "gills", "val": 0.0}, {"col": "fly_stat", "idx": "quartz", "val": 0.0}, {"col": "hat", "idx": "quartz", "val": 0.0}, {"col": "intellegence", "idx": "quartz", "val": 0.0}, {"col": "power_stat", "idx": "quartz", "va ...
# crab_pool
# <div id="visbac6209e288e4311bbe34c4d82488da1"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Dataset", "type": "x"}, {"scale": "y", "title": "Value", "type": "y"}], "data": [{"name": "table", "values": [{"col": "fly_stat", "idx": "runner", "val": 0.16}, {"col": "hat", "idx": "runner", "val": 0.0}, {"col": "intellegence", "idx": "runner", "val": 0.0}, {"col": "power_stat", "idx": "runner", "val": 0.01}, {"col": "run_stat", "idx": "runner", "val": 1.0}, {"col": "stamina_stat", "idx": "runner", "val": 0.3}, {"col": "swim_stat", "idx": "runner", "val": 0.04}, {"col": "trips", "idx": "runner", "val": 0.0}, {"col": "fly_stat", "idx": "kosmo", "val": 0.28}, {"col": "hat", "idx": "kosmo", "val": 0.0}, {"col": "intellegence", "idx": "kosmo", "val": 0.0}, {"col": "power_stat", "idx": "kosmo", "val": 0.47}, {"col": "run_stat", "idx": "kosmo", "val": 0.05}, {"col": "stamina_stat", "idx": "kosmo", "val": 0.62}, {"col": "swim_stat", "idx": "kosmo", "val": 0.06}, {"col": "trips", "idx": "kosmo", "val": 0.0}, {"col": "fly_stat", "idx": "star", "val": 0.31}, {"col": "hat", "idx": "star", "val": 0.0}, {"col": "intellegence", "idx": "star", "val": 0.0}, {"col": "power_stat", "idx": "star", "val": 0.0}, {"col": "run_stat", "idx": "star", "val": 0.49}, {"col": "stamina_stat", "idx": "star", "val": 0.33}, {"col": "swim_stat", "idx": "star", "val": 0.06}, {"col": "trips", "idx": "star", "val": 0.0}, {"col": "fly_stat", "idx": "gregg", "val": 0.08}, {"col": "hat", "idx": "gregg", "val": 0.0}, {"col": "intellegence", "idx": "gregg", "val": 0.0}, {"col": "power_stat", "idx": "gregg", "val": 0.08}, {"col": "run_stat", "idx": "gregg", "val": 0.15}, {"col": "stamina_stat", "idx": "gregg", "val": 0.32}, {"col": "swim_stat", "idx": "gregg", "val": 0.07}, {"col": "trips", "idx": "gregg", "val": 0.0}, {"col": "fly_stat", "idx": "scorpio", "val": 0.31}, {"col": "hat", "idx": "scorpio", "val": 0.0}, {"col": "intellegence", "idx": "scorpio", "val": 0.0}, {"col": "power_stat", "idx": "scorpio", "val": 0.43}, {"col": "run_stat", "idx": "scorpio", "val": 0.04}, {"col": "stamina_stat", "idx": "scorpio", "val": 0.54}, {"col": "swim_stat", "idx": "scorpio", "val": 0.04}, {"col": "trips", "idx": "scorpio", "val": 0.0}, {"col": "fly_stat", "idx": "stinky", "val": 0.08}, {"col": "hat", "idx": "stinky", "val": 0.0}, {"col": "intellegence", "idx": "stinky", "val": 0.0}, {"col": "power_stat", "idx": "stinky", "val": 0.1}, {"col": "run_stat", "idx": "stinky", "val": 0.12}, {"col": "stamina_stat", "idx": "stinky", "val": 0.59}, {"col": "swim_stat", "idx": "stinky", "val": 0.06}, {"col": "trips", "idx": "stinky", "val": 0.0}, {"col": "fly_stat", "idx": "wave", "val": 0.5}, {"col": "hat", "idx": "wave", "val": 0.0}, {"col": "intellegence", "idx": "wave", "val": 0.0}, {"col": "power_stat", "idx": "wave", "val": 0.0}, {"col": "run_stat", "idx": "wave", "val": 0.28}, {"col": "stamina_stat", "idx": "wave", "val": 0.5}, {"col": "swim_stat", "idx": "wave", "val": 0.07}, {"col": "trips", "idx": "wave", "val": 0.0}, {"col": "fly_stat", "idx": "tallone", "val": 0.45}, {"col": "hat", "idx": "tallone", "val": 0.0}, {"col": "intellegence", "idx": "tallone", "val": 0.0}, {"col": "power_stat", "idx": "tallone", "val": 0.08}, {"col": "run_stat", "idx": "tallone", "val": 0.1}, {"col": "stamina_stat", "idx": "tallone", "val": 1.0}, {"col": "swim_stat", "idx": "tallone", "val": 0.08}, {"col": "trips", "idx": "tallone", "val": 0.0}, {"col": "fly_stat", "idx": "antenna", "val": 0.1}, {"col": "hat", "idx": "antenna", "val": 0.0}, {"col": "intellegence", "idx": "antenna", "val": 0.0}, {"col": "power_stat", "idx": "antenna", "val": 0.07}, {"col": "run_stat", "idx": "antenna", "val": 0.44}, {"col": "stamina_stat", "idx": "antenna", "val": 0.81}, {"col": "swim_stat", "idx": "antenna", "val": 0.09}, {"col": "trips", "idx": "antenna", "val": 0.0}, {"col": "fly_stat", "idx": "flyer", "val": 1.0}, {"col": "hat", "idx": "flyer", "val": 0.0}, {"col": "intellegence", "idx": "flyer", "val": 0.0}, {"col": "power_stat", "idx": "flyer", "val": 0.19} ...
# crab_pool
# <div id="vis3e546f20b87e4358922ed253e4b7834d"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Dataset", "type": "x"}, {"scale": "y", "title": "Value", "type": "y"}], "data": [{"name": "table", "values": [{"col": "fly_stat", "idx": "shiny", "val": 0.91}, {"col": "hat", "idx": "shiny", "val": 0.0}, {"col": "intellegence", "idx": "shiny", "val": 0.0}, {"col": "power_stat", "idx": "shiny", "val": 0.02}, {"col": "run_stat", "idx": "shiny", "val": 0.03}, {"col": "stamina_stat", "idx": "shiny", "val": 0.41}, {"col": "swim_stat", "idx": "shiny", "val": 0.03}, {"col": "trips", "idx": "shiny", "val": 0.0}, {"col": "fly_stat", "idx": "elf", "val": 0.51}, {"col": "hat", "idx":
></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Dataset", "type": "x"}, {"scale": "y", "title": "Value", "type": "y"}], "data": [{"name": "table", "values": [{"col": "fly_stat", "idx": "zippy", "val": 0.0}, {"col": "hat", "idx": "zippy", "val": 0.0}, {"col": "intellegence", "idx": "zippy", "val": 0.0}, {"col": "power_stat", "idx": "zippy", "val": 0.0}, {"col": "run_stat", "idx": "zippy", "val": 0.51}, {"col": "stamina_stat", "idx": "zippy", "val": 0.49}, {"col": "swim_stat", "idx": "zippy", "val": 0.19}, {"col": "trips", "idx": "zippy", "val": 0.0}, {"col": "fly_stat", "idx": "melody", "val": 0.0}, {"col": "hat", "idx": "melody", "val": 0.0}, {"col": "intellegence", "idx": "melody", "val": 0.0}, {"col": "power_stat", "idx": "melody", "val": 0.51}, {"col": "run_stat", "idx": "melody", "val": 0.02}, {"col": "stamina_stat", "idx": "melody", "val": 0.38}, {"col": "swim_stat", "idx": "melody", "val": 0.21}, {"col": "trips", "idx": "melody", "val": 0.0}, {"col": "fly_stat", "idx": "woody", "val": 0.35}, {"col": "hat", "idx": "woody", "val": 1.0}, {"col": "intellegence", "idx": "woody", "val": 0.0}, {"col": "power_stat", "idx": "woody", "val": 0.02}, {"col": "run_stat", "idx": "woody", "val": 0.1}, {"col": "stamina_stat", "idx": "woody", "val": 0.4}, {"col": "swim_stat", "idx": "woody", "val": 0.29}, {"col": "trips", "idx": "woody", "val": 0.0}, {"col": "fly_stat", "idx": "papoose", "val": 0.04}, {"col": "hat", "idx": "papoose", "val": 0.0}, {"col": "intellegence", "idx": "papoose", "val": 0.0}, {"col": "power_stat", "idx": "papoose", "val": 0.2}, {"col": "run_stat", "idx": "papoose", "val": 0.38}, {"col": "stamina_stat", "idx": "papoose", "val": 0.24}, {"col": "swim_stat", "idx": "papoose", "val": 0.19}, {"col": "trips", "idx": "papoose", "val": 0.0}, {"col": "fly_stat", "idx": "buddy", "val": 0.19}, {"col": "hat", "idx": "buddy", "val": 0.0}, {"col": "intellegence", "idx": "buddy", "val": 0.0}, {"col": "power_stat", "idx": "buddy", "val": 0.09}, {"col": "run_stat", "idx": "buddy", "val": 0.19}, {"col": "stamina_stat", "idx": "buddy", "val": 0.26}, {"col": "swim_stat", "idx": "buddy", "val": 0.34}, {"col": "trips", "idx": "buddy", "val": 0.0}, {"col": "fly_stat", "idx": "pinky", "val": 0.11}, {"col": "hat", "idx": "pinky", "val": 0.0}, {"col": "intellegence", "idx": "pinky", "val": 0.0}, {"col": "power_stat", "idx": "pinky", "val": 0.11}, {"col": "run_stat", "idx": "pinky", "val": 0.17}, {"col": "stamina_stat", "idx": "pinky", "val": 0.33}, {"col": "swim_stat", "idx": "pinky", "val": 0.35}, {"col": "trips", "idx": "pinky", "val": 0.0}, {"col": "fly_stat", "idx": "peaches", "val": 0.24}, {"col": "hat", "idx": "peaches", "val": 0.0}, {"col": "intellegence", "idx": "peaches", "val": 0.0}, {"col": "power_stat", "idx": "peaches", "val": 0.13}, {"col": "run_stat", "idx": "peaches", "val": 0.41}, {"col": "stamina_stat", "idx": "peaches", "val": 0.17}, {"col": "swim_stat", "idx": "peaches", "val": 0.27}, {"col": "trips", "idx": "peaches", "val": 0.0}, {"col": "fly_stat", "idx": "powim", "val": 0.01}, {"col": "hat", "idx": "powim", "val": 1.0}, {"col": "intellegence", "idx": "powim", "val": 0.0}, {"col": "power_stat", "idx": "powim", "val": 0.14}, {"col": "run_stat", "idx": "powim", "val": 0.03}, {"col": "stamina_stat", "idx": "powim", "val": 0.39}, {"col": "swim_stat", "idx": "powim", "val": 0.47}, {"col": "trips", "idx": "powim", "val": 0.0}, {"col": "fly_stat", "idx": "gills", "val": 0.25}, {"col": "hat", "idx": "gills", "val": 0.0}, {"col": "intellegence", "idx": "gills", "val": 0.0}, {"col": "power_stat", "idx": "gills", "val": 0.02}, {"col": "run_stat", "idx": "gills", "val": 0.03}, {"col": "stamina_stat", "idx": "gills", "val": 0.68}, {"col": "swim_stat", "idx": "gills", "val": 0.48}, {"col": "trips", "idx": "gills", "val": 0.0}, {"col": "fly_stat", "idx": "quartz", "val": 0.0}, {"col": "hat", "idx": "quartz", "val": 0.0}, {"col": "intellegence", "idx": "quartz", "val": 0.0}, {"col": "power_stat", "idx": "quartz", "val": 0.19} ...
# crab_pool
# <div id="visa7837e4578204833a3bfbdd090ab8727"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Dataset", "type": "x"}, {"scale": "y", "title": "Value", "type": "y"}], "data": [{"name": "table", "values": [{"col": "fly_stat", "idx": "casino", "val": 0.0}, {"col": "hat", "idx": "casino", "val": 0.0}, {"col": "intellegence", "idx": "casino", "val": 0.0}, {"col": "power_stat", "idx": "casino", "val": 0.19}, {"col": "run_stat", "idx": "casino", "val": 0.43}, {"col": "stamina_stat", "idx": "casino", "val": 0.46}, {"col": "swim_stat", "idx": "casino", "val": 0.03}, {"col": "trips", "idx": "casino", "val": 0.0}, {"col": "fly_stat", "idx": "kosmo", "val": 0.28}, {"col": "hat", "idx": "kosmo", "val": 0.0}, {"col": "intellegence", "idx": "kosmo", "val": 0.0}, {"col": "power_stat", "idx": "kosmo", "val": 0.47}, {"col": "run_stat", "idx": "kosmo", "val": 0.05}, {"col": "stamina_stat", "idx": "kosmo", "val": 0.62}, {"col": "swim_stat", "idx": "kosmo", "val": 0.06}, {"col": "trips", "idx": "kosmo", "val": 0.0}, {"col": "fly_stat", "idx": "star", "val": 0.31}, {"col": "hat", "idx": "star", "val": 0.0}, {"col": "intellegence", "idx": "star", "val": 0.0}, {"col": "power_stat", "idx": "star", "val": 0.0}, {"col": "run_stat", "idx": "star", "val": 0.49}, {"col": "stamina_stat", "idx": "star", "val": 0.33}, {"col": "swim_stat", "idx": "star", "val": 0.06}, {"col": "trips", "idx": "star", "val": 0.0}, {"col": "fly_stat", "idx": "stinky", "val": 0.08}, {"col": "hat", "idx": "stinky", "val": 0.0}, {"col": "intellegence", "idx": "stinky", "val": 0.0}, {"col": "power_stat", "idx": "stinky", "val": 0.1}, {"col": "run_stat", "idx": "stinky", "val": 0.12},
val": 0.0}, {"col": "fly_stat", "idx": "chaosm", "val": 0.06}, {"col": "hat", "idx": "chaosm", "val": 0.0}, {"col": "intellegence", "idx": "chaosm", "val": 0.0}, {"col": "power_stat", "idx": "chaosm", "val": 0.17}, {"col": "run_stat", "idx": "chaosm", "val": 0.08}, {"col": "stamina_stat", "idx": "chaosm", "val": 0.72}, {"col": "swim_stat", "idx": "chaosm", "val": 0.52}, {"col": "trips", "idx": "chaosm", "val": 0.0}, {"col": "fly_stat", "idx": "cascade", "val": 0.08}, {"col": "hat", "idx": "cascade", "val": 0.0}, {"col": "intellegence", "idx": "cascade", "val": 0.0}, {"col": "power_stat", "idx": "cascade", "val": 0.0}, {"col": "run_stat", "idx": "cascade", "val": 0.22}, {"col": "stamina_stat", "idx": "cascade", "val": 0.4}, {"col": "swim_stat", "idx": "cascade", "val": 0.5}, {"col": "trips", "idx": "cascade", "val": 0.0}, {"col": "fly_stat", "idx": "echo", "val": 0.01}, {"col": "hat", "idx": "echo", "val": 0.0}, {"col": "intellegence", "idx": "echo", "val": 0.0}, {"col": "power_stat", "idx": "echo", "val": 0.0}, {"col": "run_stat", "idx": "echo", "val": 0.25}, {"col": "stamina_stat", "idx": "echo", "val": 0.68}, {"col": "swim_stat", "idx": "echo", "val": 0.52}, {"col": "trips", "idx": "echo", "val": 0.0}, {"col": "fly_stat", "idx": "quartz", "val": 0.0}, {"col": "hat", "idx": "quartz", "val": 0.0}, {"col": "intellegence", "idx": "quartz", "val": 0.0}, {"col": "power_stat", " ...
# crab_pool
# <div id="visc0659649e3274c95928b8eb8ee18b211"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Dataset", "type": "x"}, {"scale": "y", "title": "Value", "type": "y"}], "data": [{"name": "table", "values": [{"col": "fly_stat", "idx": "pebbles", "val": 0.44}, {"col": "hat", "idx": "pebbles", "val": 0.0}, {"col": "intellegence", "idx": "pebbles", "val": 0.0}, {"col": "power_stat", "idx": "pebbles", "val": 0.0}, {"col": "run_stat", "idx": "pebbles", "val": 0.27}, {"col": "stamina_stat", "idx": "pebbles", "val": 0.39}, {"col": "swim_stat", "idx": "pebbles", "val": 0.04}, {"col": "trips", "idx": "pebbles", "val": 0.0}, {"col": "fly_stat", "idx": "wario", "val": 0.06}, {"col": "hat", "idx": "wario", "val": 0.0}, {"col": "intellegence", "idx": "wario", "val": 0.0}, {"col": "power_stat", "idx": "wario", "val": 0.25}, {"col": "run_stat", "idx": "wario", "val": 0.09}, {"col": "stamina_stat", "idx": "wario", "val": 0.33}, {"col": "swim_stat", "idx": "wario", "val": 0.1}, {"col": "trips", "idx": "wario", "val": 0.0}, {"col": "fly_stat", "idx": "chaobob", "val": 0.09}, {"col": "hat", "idx": "chaobob", "val": 0.0}, {"col": "intellegence", "idx": "chaobob", "val": 0.0}, {"col": "power_stat", "idx": "chaobob", "val": 0.45}, {"col": "run_stat", "idx":
></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
# ...
# overall
# <div id="vis493f7254243b4afe9b0c4f70316f0ab4"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Dataset", "type": "x"}, {"scale": "y", "title": "Value", "type": "y"}], "data": [{"name": "table", "values": [{"col": "fly_stat", "idx": "wave", "val": 0.5}, {"col": "hat", "idx": "wave", "val": 0.0}, {"col": "intellegence", "idx": "wave", "val": 0.0}, {"col": "power_stat", "idx": "wave", "val": 0.0}, {"col": "run_stat", "idx": "wave", "val": 0.28}, {"col": "stamina_stat", "idx": "wave", "val": 0.5}, {"col": "swim_stat", "idx": "wave", "val": 0.07}, {"col": "trips", "idx": "wave", "val": 0.0}, {"col": "fly_stat", "idx": "antenna", "val": 0.1}, {"col": "hat", "idx": "antenna", "val": 0.0}, {"col": "intellegence", "idx": "antenna", "val": 0.0}, {"col": "power_stat", "idx": "antenna", "val": 0.07}, {"col": "run_stat", "idx": "antenna", "val": 0.44}, {"col": "stamina_stat", "idx": "antenna", "val": 0.81}, {"col": "swim_stat", "idx": "antenna", "val": 0.09}, {"col": "trips", "idx": "antenna", "val": 0.0}, {"col": "fly_stat", "idx": "hiya", "val": 0.0}, {"col": "hat", "idx": "hiya", "val": 0.0}, {"col": "intellegence", "idx": "hiya", "val": 0.0}, {"col": "power_stat", "idx": "hiya", "val": 0.55}, {"col": "run_stat", "idx": "hiya", "val": 0.02}, {"col": "stamina_stat", "idx": "hiya", "val": 0.37}, {"col": "swim_stat", "idx": "hiya", "val": 0.22}, {"col": "trips", "idx": "hiya", "val": 0.0}, {"col": "fly_stat", "idx": "flyer", "val": 1.0}, {"col": "hat", "idx": "flyer", "val": 0.0}, {"col": "intellegence", "idx": "flyer", "val": 0.0}, {"col": "power_stat", "idx": "flyer", "val": 0.19}, {"col": "run_stat", "idx": "flyer", "val": 0.02}, {"col": "stamina_stat", "idx": "flyer", "val": 0.29}, {"col": "swim_stat", "idx": "flyer", "val": 0.24}, {"col": "trips", "idx": "flyer", "val": 0.0}, {"col": "fly_stat", "idx": "ziggy", "val": 0.25}, {"col": "hat", "idx": "ziggy", "val": 0.0}, {"col": "intellegence", "idx": "ziggy", "val": 0.0}, {"col": "power_stat", "idx": "ziggy", "val": 0.03}, {"col": "run_stat", "idx": "ziggy", "val": 0.04}, {"col": "stamina_stat", "idx": "ziggy", "val": 0.54}, {"col": "swim_stat", "idx": "ziggy", "val": 0.57}, {"col": "trips", "idx": "ziggy", "val": 0.0}, {"col": "fly_stat", "idx": "echo", "val": 0.01}, {"col": "hat", "idx": "echo", "val": 0.0}, {"col": "intellegence", "idx": "echo", "val": 0.0}, {"col": "power_stat", "idx": "echo", "val": 0.0}, {"col": "run_stat", "idx": "echo", "val": 0.25}, {"col": "stamina_stat", "idx": "echo", "val": 0.68}, {"col": "swim_stat", "idx": "echo", "val": 0.52}, {"col": "trips", "idx": "echo", "val": 0.0}, {"col": "fly_stat", "idx": "star", "val": 0.31}, {"col": "hat", "idx": "star", "val": 0.0}, {"col": "intellegence", "idx": "star", "val": 0.0}, {"col": "power_stat", "idx": "star", "val": 0.0}, {"col": "run_stat", "idx": "star", "val": 0.49}, {"col": "stamina_stat", "idx": "star", "val": 0.33}, {"col": "swim_stat", "idx": "star", "val": 0.06}, {"col": "trips", "idx": "star", "val": 0.0}, {"col": "fly_stat", "idx": "buddy", "val": 0.19}, {"col": "hat", "idx": "buddy", "val": 0.0}, {"col": "intellegence", "idx": "buddy", "val": 0.0}, {"col": "power_stat", "idx": "buddy", "val": 0.09}, {"col": "run_stat", "idx": "buddy", "val": 0.19}, {"col": "stamina_stat", "idx": "buddy", "val": 0.26}, {"col": "swim_stat", "idx": "buddy", "val": 0.34}, {"col": "trips", "idx": "buddy", "val": 0.0}, {"col": "fly_stat", "idx": "dash", "val": 0.0}, {"col": "hat", "idx": "dash", "val": 0.0}, {"col": "intellegence", "idx": "dash", "val": 0.0}, {"col": "power_stat", "idx": "dash", "val": 0.05}, {"col": "run_stat", "idx": "dash", "val": 0.44}, {"col": "stamina_stat", "idx": "dash", "val": 0.38}, {"col": "swim_stat", "idx": "dash", "val": 0.22}, {"col": "trips", "idx": "dash", "val": 0.0}, {"col": "fly_stat", "idx": "WOW", "val": 0.03}, {"col": "hat", "idx": "WOW", "val": 0.0}, {"col": "intellegence", "idx": "WOW", "val": 0.0}, {"col": "power_stat", "idx": "WOW", "val": 0.47}, {"col": "run_stat", "idx": "WOW", "val": 0.1}, {"col": "stamina_stat", "idx" ...
# overall
# <div id="vise748619e1c634d1bab96d55af24571ff"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Dataset", "type": "x"}, {"scale": "y", "title": "Value", "type": "y"}], "data": [{"name": "table", "values": [{"col": "fly_stat", "idx": "runfly", "val": 0.6}, {"col": "hat", "idx": "runfly", "val": 1.0}, {"col": "intellegence", "idx": "runfly", "val": 0.0}, {"col": "power_stat", "idx": "runfly", "val": 0.01}, {"col": "run_stat", "idx": "runfly", "val": 0.18}, {"col": "stamina_stat", "idx": "runfly", "val": 0.43}, {"col": "swim_stat", "idx": "runfly", "val": 0.04}, {"col": "trips", "idx": "runfly", "val": 0.0}, {"col": "fly_stat", "idx": "atom", "val": 0.07}, {"col": "hat", "idx": "atom", "val": 0.0}, {"col": "intellegence", "idx": "atom", "val": 0.0}, {"col": "power_stat", "idx": "atom", "val": 0.44}, {"col": "run_stat", "idx": "atom", "val": 0.25}, {"col": "stamina_stat", "idx": "atom", "val": 0.58}, {"col": "swim_stat", "idx": "atom", "val": 0.04}, {"col": "trips", "idx": "atom", "val": 0.0
></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Dataset", "type": "x"}, {"scale": "y", "title": "Value", "type": "y"}], "data": [{"name": "table", "values": [{"col": "fly_stat", "idx": "ownerbm", "val": 0.04}, {"col": "hat", "idx": "ownerbm", "val": 0.0}, {"col": "intellegence", "idx": "ownerbm", "val": 0.0}, {"col": "power_stat", "idx": "ownerbm", "val": 0.01}, {"col": "run_stat", "idx": "ownerbm", "val": 0.01}, {"col": "stamina_stat", "idx": "ownerbm", "val": 0.95}, {"col": "swim_stat", "idx": "ownerbm", "val": 0.37}, {"col": "trips", "idx": "ownerbm", "val": 1.0}, {"col": "fly_stat", "idx": "jester", "val": 0.72}, {"col": "hat", "idx": "jester", "val": 0.0}, {"col": "intellegence", "idx": "jester", "val": 0.0}, {"col": "power_stat", "idx": "jester", "val": 0.0}, {"col": "run_stat", "idx": "jester", "val": 0.02}, {"col": "stamina_stat", "idx": "jester", "val": 0.51}, {"col": "swim_stat", "idx": "jester", "val": 0.04}, {"col": "trips", "idx": "jester", "val": 0.0}, {"col": "fly_stat", "idx": "gregg", "val": 0.08}, {"col": "hat", "idx": "gregg", "val": 0.0}, {"col": "intellegence", "idx": "gregg", "val": 0.0}, {"col": "power_stat", "idx": "gregg", "val": 0.08}, {"col": "run_stat", "idx": "gregg", "val": 0.15}, {"col": "stamina_stat", "idx": "gregg", "val": 0.32}, {"col": "swim_stat", "idx": "gregg", "val": 0.07}, {"col": "trips", "idx": "gregg", "val": 0.0}, {"col": "fly_stat", "idx": "scorpio", "val": 0.31}, {"col": "hat", "idx": "scorpio", "val": 0.0}, {"col": "intellegence", "idx": "scorpio", "val": 0.0}, {"col": "power_stat", "idx": "scorpio", "val": 0.43}, {"col": "run_stat", "idx": "scorpio", "val": 0.04}, {"col": "stamina_stat", "idx": "scorpio", "val": 0.54}, {"col": "swim_stat", "idx": "scorpio", "val": 0.04}, {"col": "trips", "idx": "scorpio", "val": 0.0}, {"col": "fly_stat", "idx": "cash", "val": 0.02}, {"col": "hat", "idx": "cash", "val": 0.0}, {"col": "intellegence", "idx": "cash", "val": 0.0}, {"col": "power_stat", "idx": "cash", "val": 0.48}, {"col": "run_stat", "idx": "cash", "val": 0.05}, {"col": "stamina_stat", "idx": "cash", "val": 0.31}, {"col": "swim_stat", "idx": "cash", "val": 0.04}, {"col": "trips", "idx": "cash", "val": 0.0}, {"col": "fly_stat", "idx": "shiny", "val": 0.91}, {"col": "hat", "idx": "shiny", "val": 0.0}, {"col": "intellegence", "idx": "shiny", "val": 0.0}, {"col": "power_stat", "idx": "shiny", "val": 0.02}, {"col": "run_stat", "idx": "shiny", "val": 0.03}, {"col": "stamina_stat", "idx": "shiny", "val": 0.41}, {"col": "swim_stat", "idx": "shiny", "val": 0.03}, {"col": "trips", "idx": "shiny", "val": 0.0}, {"col": "fly_stat", "idx": "stinky", "val": 0.08}, {"col": "hat", "idx": "stinky", "val": 0.0}, {"col": "intellegence", "idx": "stinky", "val": 0.0}, {"col": "power_stat", "idx": "stinky", "val": 0.1}, {"col": "run_stat", "idx": "stinky", "val": 0.12}, {"col": "stamina_stat", "idx": "stinky", "val": 0.59}, {"col": "swim_stat", "idx": "stinky", "val": 0.06}, {"col": "trips", "idx": "stinky", "val": 0.0}, {"col": "fly_stat", "idx": "bruno", "val": 0.19}, {"col": "hat", "idx": "bruno", "val": 0.0}, {"col": "intellegence", "idx": "bruno", "val": 0.0}, {"col": "power_stat", "idx": "bruno", "val": 0.45}, {"col": "run_stat", "idx": "bruno", "val": 0.02}, {"col": "stamina_stat", "idx": "bruno", "val": 0.61}, {"col": "swim_stat", "idx": "bruno", "val": 0.04}, {"col": "trips", "idx": "bruno", "val": 0.0}, {"col": "fly_stat", "idx": "spike", "val": 0.55}, {"col": "hat", "idx": "spike", "val": 0.0}, {"col": "intellegence", "idx": "spike", "val": 0.0}, {"col": "power_stat", "idx": "spike", "val": 0.19}, {"col": "run_stat", "idx": "spike", "val": 0.02}, {"col": "stamina_stat", "idx": "spike", "val": 0.36}, {"col": "swim_stat", "idx": "spike", "val": 0.04}, {"col": "trips", "idx": "spike", "val": 0.0}, {"col": "fly_stat", "idx": "elf", "val": 0.51}, {"col": "hat", "idx": "elf", "val": 0.0}, {"col": "intellegence", "idx": "elf", "val": 0.0}, {"col": "power_stat", "idx": "elf", "val": 0.0}, {"col" ...

# %%
course = "onix"

# execute SQL select statement
cursor.execute("SELECT * FROM predictions WHERE course = '"+course+"' ORDER BY -round3 DESC, -round2 DESC, -round1 DESC;")

# get the number of rows in the resultset
numrows = int(cursor.rowcount)

prev_score = 200
index = range(0,17,1)
for x in range(0,numrows):
    row = cursor.fetchone()
    chao_name = row[1]
    print chao_name
    data_dict = {
        "predictions": list(row[3:20]),
        "prediction_names": prediction_names,
        "round1": ([row[20]] if row[20] is not None else [0])*17,
        "round2": ([row[21]-0.1] if row[21] is not None else [0])*17,
        "round3": ([row[22]-0.2] if row[22] is not None else [0])*17
    }
    predictions_df = pd.DataFrame(data_dict, index=index)
#     print predictions_df
    line = vincent.Line(predictions_df, 
                        columns=["predictions", "round1", "round2", "round3"], 
                         key_on="prediction_names"
                        )
    line.axis_titles(x='', y='place')
    line.legend(title='Categories')
    line.width = 700
    line.height = 150
    line.scales[0].type = 'ordinal'
    line.axes[0].properties = AxisProperties(
    labels=PropertySet(
        angle=ValueRef(value=45),
        align=ValueRef(value='left')
        )
    )
    line.display()
# Out:
# zippy
# <div id="vis9bc460ab2ebf4f5ca4af76012c1e994c"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"labels": {"align": {"value": "left"}, "angle": {"value": 45}}}, "scale": "x", "title": "", "type": "x"}, {"scale": "y", "title": "place", "type": "y"}], "data": [{"name": "table", "values": [{"col": "predictions", "idx": "filtered_stochastic", "val": 13.0}, {"col": "round1", "idx": "filtered_stochastic", "val": 1.0}, {"col": "round2", "idx": "filtered_stochastic", "val": 0.9}, {"col": "round3", "idx": "filtered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic", "val": 10.0}, {"col": "round1", "idx": "unfiltered_stochastic", "val": 1.0}, {"col": "round2", "idx": "unfiltered_stochastic", "val": 0.9}, {"col": "round3", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch", "val": 13.0}, {"col": "round1", "idx": "filtered_batch", "val": 1.0}, {"col": "round2", "idx": "filtered_batch", "val": 0.9}, {"col": "round3", "idx": "filtered_batch", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch", "val": 10.0}, {"col": "round1", "idx": "unfiltered_batch", "val": 1.0}, {"col": "round2", "idx": "unfiltered_batch", "val": 0.9}, {"col": "round3", "idx": "unfiltered_batch", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_final", "val": 13.0}, {"col": "round1", "idx": "filtered_stochastic_final", "val": 1.0}, {"col": "round2", "idx": "filtered_stochastic_final", "val": 0.9}, {"col": "round3", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_final", "val": 10.0}, {"col": "round1", "idx": "unfiltered_stochastic_final", "val": 1.0}, {"col": "round2", "idx": "unfiltered_stochastic_final", "val": 0.9}, {"col": "round3", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_final", "val": 13.0}, {"col": "round1", "idx": "filtered_batch_final", "val": 1.0}, {"col": "round2", "idx": "filtered_batch_final", "val": 0.9}, {"col": "round3", "idx": "filtered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_final", "val": 10.0}, {"col": "round1", "idx": "unfiltered_batch_final", "val": 1.0}, {"col": "round2", "idx": "unfiltered_batch_final", "val": 0.9}, {"col": "round3", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_power", "val": 4.0}, {"col": "round1", "idx": "filtered_stochastic_power", "val": 1.0}, {"col": "round2", "idx": "filtered_stochastic_power", "val": 0.9}, {"col": "round3", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_power", "val": 7.0}, {"col": "round1", "idx": "unfiltered_stochastic_power", "val": 1.0}, {"col": "round2", "idx": "unfiltered_stochastic_power", "val": 0.9}, {"col": "round3", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_power", "val": 4.0}, {"col": "round1", "idx": "filtered_batch_power", "val": 1.0}, {"col": "round2", "idx": "filtered_batch_power", "val": 0.9}, {"col": "round3", "idx": "filtered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_power", "val": 7.0}, {"col": "round1", "idx": "unfiltered_batch_power", "val": 1.0}, {"col": "round2", "idx": "unfiltered_batch_power", "val": 0.9}, {"col": "round3", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_fina_power", "val": 4.0}, {"col": "round1", "idx": "filtered_stochastic_fina_power", "val": 1.0}, {"col": "round2", "idx": "filtered_stochastic_fina_power", "val": 0.9}, {"col": "round3", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochasticl_final_power", "val": 7.0}, {"col": "round1", "idx": "unfiltered_stochasticl_final_power", "val": 1.0}, {"col": "round2", "idx": "unfiltered_stochasticl_final_power", "val": 0.9}, {"col": "round3", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_bat ...
#          chart({el: "#vis9bc460ab2ebf4f5ca4af76012c1e994c"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# runner
# <div id="visab379f0f0e434d08b008d3d4c44d718e"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"labels": {"align": {"value": "left"}, "angle": {"value": 45}}}, "scale": "x", "title": "", "type": "x"}, {"scale": "y", "title": "place", "type": "y"}], "data": [{"name": "table", "values": [{"col": "predictions", "idx": "filtered_stochastic", "val": 2.0}, {"col": "round1", "idx": "filtered_stochastic", "val": 3.0}, {"col": "round2", "idx": "filtered_stochastic", "val": 1.9}, {"col": "round3", "idx": "filtered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic", "val": 2.0}, {"col": "round1", "idx": "unfiltered_stochastic", "val": 3.0}, {"col": "round2", "idx": "unfiltered_stochastic", "val": 1.9}, {"col": "round3", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch", "val": 2.0}, {"col": "round1", "idx": "filtered_batch", "val": 3.0}, {"col": "round2", "idx": "filtered_batch", "val": 1.9}, {"col": "round3", "idx": "filtered_batch", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch", "val": 2.0}, {"col": "round1", "idx": "unfiltered_batch", "val": 3.0}, {"col": "round2", "idx": "unfiltered_batch", "val": 1.9}, {"col": "round3", "idx": "unfiltered_batch", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_final", "val": 2.0}, {"col": "round1", "idx": "filtered_stochastic_final", "val": 3.0}, {"col": "round2", "idx": "filtered_stochastic_final", "val": 1.9}, {"col": "round3", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_final", "val": 2.0}, {"col": "round1", "idx": "unfiltered_stochastic_final", "val": 3.0}, {"col": "round2", "idx": "unfiltered_stochastic_final", "val": 1.9}, {"col": "round3", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_final", "val": 2.0}, {"col": "round1", "idx": "filtered_batch_final", "val": 3.0}, {"col": "round2", "idx": "filtered_batch_final", "val": 1.9}, {"col": "round3", "idx": "filtered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_final", "val": 2.0}, {"col": "round1", "idx": "unfiltered_batch_final", "val": 3.0}, {"col": "round2", "idx": "unfiltered_batch_final", "val": 1.9}, {"col": "round3", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_power", "val": 12.0}, {"col": "round1", "idx": "filtered_stochastic_power", "val": 3.0}, {"col": "round2", "idx": "filtered_stochastic_power", "val": 1.9}, {"col": "round3", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_power", "val": 12.0}, {"col": "round1", "idx": "unfiltered_stochastic_power", "val": 3.0}, {"col": "round2", "idx": "unfiltered_stochastic_power", "val": 1.9}, {"col": "round3", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_power", "val": 12.0}, {"col": "round1", "idx": "filtered_batch_power", "val": 3.0}, {"col": "round2", "idx": "filtered_batch_power", "val": 1.9}, {"col": "round3", "idx": "filtered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_power", "val": 12.0}, {"col": "round1", "idx": "unfiltered_batch_power", "val": 3.0}, {"col": "round2", "idx": "unfiltered_batch_power", "val": 1.9}, {"col": "round3", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_fina_power", "val": 12.0}, {"col": "round1", "idx": "filtered_stochastic_fina_power", "val": 3.0}, {"col": "round2", "idx": "filtered_stochastic_fina_power", "val": 1.9}, {"col": "round3", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochasticl_final_power", "val": 12.0}, {"col": "round1", "idx": "unfiltered_stochasticl_final_power", "val": 3.0}, {"col": "round2", "idx": "unfiltered_stochasticl_final_power", "val": 1.9}, {"col": "round3", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch ...
#          chart({el: "#visab379f0f0e434d08b008d3d4c44d718e"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# peaches
# <div id="visceececbb0e0c43a2b29bd106fcff7ad8"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"labels": {"align": {"value": "left"}, "angle": {"value": 45}}}, "scale": "x", "title": "", "type": "x"}, {"scale": "y", "title": "place", "type": "y"}], "data": [{"name": "table", "values": [{"col": "predictions", "idx": "filtered_stochastic", "val": 9.0}, {"col": "round1", "idx": "filtered_stochastic", "val": 8.0}, {"col": "round2", "idx": "filtered_stochastic", "val": 2.9}, {"col": "round3", "idx": "filtered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic", "val": 21.0}, {"col": "round1", "idx": "unfiltered_stochastic", "val": 8.0}, {"col": "round2", "idx": "unfiltered_stochastic", "val": 2.9}, {"col": "round3", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch", "val": 9.0}, {"col": "round1", "idx": "filtered_batch", "val": 8.0}, {"col": "round2", "idx": "filtered_batch", "val": 2.9}, {"col": "round3", "idx": "filtered_batch", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch", "val": 21.0}, {"col": "round1", "idx": "unfiltered_batch", "val": 8.0}, {"col": "round2", "idx": "unfiltered_batch", "val": 2.9}, {"col": "round3", "idx": "unfiltered_batch", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_final", "val": 9.0}, {"col": "round1", "idx": "filtered_stochastic_final", "val": 8.0}, {"col": "round2", "idx": "filtered_stochastic_final", "val": 2.9}, {"col": "round3", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_final", "val": 21.0}, {"col": "round1", "idx": "unfiltered_stochastic_final", "val": 8.0}, {"col": "round2", "idx": "unfiltered_stochastic_final", "val": 2.9}, {"col": "round3", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_final", "val": 9.0}, {"col": "round1", "idx": "filtered_batch_final", "val": 8.0}, {"col": "round2", "idx": "filtered_batch_final", "val": 2.9}, {"col": "round3", "idx": "filtered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_final", "val": 21.0}, {"col": "round1", "idx": "unfiltered_batch_final", "val": 8.0}, {"col": "round2", "idx": "unfiltered_batch_final", "val": 2.9}, {"col": "round3", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_power", "val": 13.0}, {"col": "round1", "idx": "filtered_stochastic_power", "val": 8.0}, {"col": "round2", "idx": "filtered_stochastic_power", "val": 2.9}, {"col": "round3", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_power", "val": 11.0}, {"col": "round1", "idx": "unfiltered_stochastic_power", "val": 8.0}, {"col": "round2", "idx": "unfiltered_stochastic_power", "val": 2.9}, {"col": "round3", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_power", "val": 13.0}, {"col": "round1", "idx": "filtered_batch_power", "val": 8.0}, {"col": "round2", "idx": "filtered_batch_power", "val": 2.9}, {"col": "round3", "idx": "filtered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_power", "val": 11.0}, {"col": "round1", "idx": "unfiltered_batch_power", "val": 8.0}, {"col": "round2", "idx": "unfiltered_batch_power", "val": 2.9}, {"col": "round3", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_fina_power", "val": 13.0}, {"col": "round1", "idx": "filtered_stochastic_fina_power", "val": 8.0}, {"col": "round2", "idx": "filtered_stochastic_fina_power", "val": 2.9}, {"col": "round3", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochasticl_final_power", "val": 11.0}, {"col": "round1", "idx": "unfiltered_stochasticl_final_power", "val": 8.0}, {"col": "round2", "idx": "unfiltered_stochasticl_final_power", "val": 2.9}, {"col": "round3", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_b ...
#          chart({el: "#visceececbb0e0c43a2b29bd106fcff7ad8"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# papoose
# <div id="visf77738eb07674198a42983bee5e288d7"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"labels": {"align": {"value": "left"}, "angle": {"value": 45}}}, "scale": "x", "title": "", "type": "x"}, {"scale": "y", "title": "place", "type": "y"}], "data": [{"name": "table", "values": [{"col": "predictions", "idx": "filtered_stochastic", "val": 20.0}, {"col": "round1", "idx": "filtered_stochastic", "val": 6.0}, {"col": "round2", "idx": "filtered_stochastic", "val": 3.9}, {"col": "round3", "idx": "filtered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic", "val": 23.0}, {"col": "round1", "idx": "unfiltered_stochastic", "val": 6.0}, {"col": "round2", "idx": "unfiltered_stochastic", "val": 3.9}, {"col": "round3", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch", "val": 20.0}, {"col": "round1", "idx": "filtered_batch", "val": 6.0}, {"col": "round2", "idx": "filtered_batch", "val": 3.9}, {"col": "round3", "idx": "filtered_batch", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch", "val": 23.0}, {"col": "round1", "idx": "unfiltered_batch", "val": 6.0}, {"col": "round2", "idx": "unfiltered_batch", "val": 3.9}, {"col": "round3", "idx": "unfiltered_batch", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_final", "val": 20.0}, {"col": "round1", "idx": "filtered_stochastic_final", "val": 6.0}, {"col": "round2", "idx": "filtered_stochastic_final", "val": 3.9}, {"col": "round3", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_final", "val": 23.0}, {"col": "round1", "idx": "unfiltered_stochastic_final", "val": 6.0}, {"col": "round2", "idx": "unfiltered_stochastic_final", "val": 3.9}, {"col": "round3", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_final", "val": 20.0}, {"col": "round1", "idx": "filtered_batch_final", "val": 6.0}, {"col": "round2", "idx": "filtered_batch_final", "val": 3.9}, {"col": "round3", "idx": "filtered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_final", "val": 23.0}, {"col": "round1", "idx": "unfiltered_batch_final", "val": 6.0}, {"col": "round2", "idx": "unfiltered_batch_final", "val": 3.9}, {"col": "round3", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_power", "val": 15.0}, {"col": "round1", "idx": "filtered_stochastic_power", "val": 6.0}, {"col": "round2", "idx": "filtered_stochastic_power", "val": 3.9}, {"col": "round3", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_power", "val": 10.0}, {"col": "round1", "idx": "unfiltered_stochastic_power", "val": 6.0}, {"col": "round2", "idx": "unfiltered_stochastic_power", "val": 3.9}, {"col": "round3", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_power", "val": 15.0}, {"col": "round1", "idx": "filtered_batch_power", "val": 6.0}, {"col": "round2", "idx": "filtered_batch_power", "val": 3.9}, {"col": "round3", "idx": "filtered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_power", "val": 10.0}, {"col": "round1", "idx": "unfiltered_batch_power", "val": 6.0}, {"col": "round2", "idx": "unfiltered_batch_power", "val": 3.9}, {"col": "round3", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_fina_power", "val": 15.0}, {"col": "round1", "idx": "filtered_stochastic_fina_power", "val": 6.0}, {"col": "round2", "idx": "filtered_stochastic_fina_power", "val": 3.9}, {"col": "round3", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochasticl_final_power", "val": 10.0}, {"col": "round1", "idx": "unfiltered_stochasticl_final_power", "val": 6.0}, {"col": "round2", "idx": "unfiltered_stochasticl_final_power", "val": 3.9}, {"col": "round3", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "predictions", "idx": "filter ...
#          chart({el: "#visf77738eb07674198a42983bee5e288d7"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# dolphin
# <div id="vis6cddf5d655d74664a9318daab28d3ef2"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"labels": {"align": {"value": "left"}, "angle": {"value": 45}}}, "scale": "x", "title": "", "type": "x"}, {"scale": "y", "title": "place", "type": "y"}], "data": [{"name": "table", "values": [{"col": "predictions", "idx": "filtered_stochastic", "val": 4.0}, {"col": "round1", "idx": "filtered_stochastic", "val": 21.0}, {"col": "round2", "idx": "filtered_stochastic", "val": 4.9}, {"col": "round3", "idx": "filtered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic", "val": 5.0}, {"col": "round1", "idx": "unfiltered_stochastic", "val": 21.0}, {"col": "round2", "idx": "unfiltered_stochastic", "val": 4.9}, {"col": "round3", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch", "val": 4.0}, {"col": "round1", "idx": "filtered_batch", "val": 21.0}, {"col": "round2", "idx": "filtered_batch", "val": 4.9}, {"col": "round3", "idx": "filtered_batch", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch", "val": 5.0}, {"col": "round1", "idx": "unfiltered_batch", "val": 21.0}, {"col": "round2", "idx": "unfiltered_batch", "val": 4.9}, {"col": "round3", "idx": "unfiltered_batch", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_final", "val": 4.0}, {"col": "round1", "idx": "filtered_stochastic_final", "val": 21.0}, {"col": "round2", "idx": "filtered_stochastic_final", "val": 4.9}, {"col": "round3", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_final", "val": 5.0}, {"col": "round1", "idx": "unfiltered_stochastic_final", "val": 21.0}, {"col": "round2", "idx": "unfiltered_stochastic_final", "val": 4.9}, {"col": "round3", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_final", "val": 4.0}, {"col": "round1", "idx": "filtered_batch_final", "val": 21.0}, {"col": "round2", "idx": "filtered_batch_final", "val": 4.9}, {"col": "round3", "idx": "filtered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_final", "val": 5.0}, {"col": "round1", "idx": "unfiltered_batch_final", "val": 21.0}, {"col": "round2", "idx": "unfiltered_batch_final", "val": 4.9}, {"col": "round3", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_power", "val": 2.0}, {"col": "round1", "idx": "filtered_stochastic_power", "val": 21.0}, {"col": "round2", "idx": "filtered_stochastic_power", "val": 4.9}, {"col": "round3", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_power", "val": 3.0}, {"col": "round1", "idx": "unfiltered_stochastic_power", "val": 21.0}, {"col": "round2", "idx": "unfiltered_stochastic_power", "val": 4.9}, {"col": "round3", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_power", "val": 2.0}, {"col": "round1", "idx": "filtered_batch_power", "val": 21.0}, {"col": "round2", "idx": "filtered_batch_power", "val": 4.9}, {"col": "round3", "idx": "filtered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_power", "val": 3.0}, {"col": "round1", "idx": "unfiltered_batch_power", "val": 21.0}, {"col": "round2", "idx": "unfiltered_batch_power", "val": 4.9}, {"col": "round3", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_fina_power", "val": 2.0}, {"col": "round1", "idx": "filtered_stochastic_fina_power", "val": 21.0}, {"col": "round2", "idx": "filtered_stochastic_fina_power", "val": 4.9}, {"col": "round3", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochasticl_final_power", "val": 3.0}, {"col": "round1", "idx": "unfiltered_stochasticl_final_power", "val": 21.0}, {"col": "round2", "idx": "unfiltered_stochasticl_final_power", "val": 4.9}, {"col": "round3", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "predictions", "idx": "filter ...
#          chart({el: "#vis6cddf5d655d74664a9318daab28d3ef2"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# echo
# <div id="vis4eb9402e04ae40129602eaae8c162583"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"labels": {"align": {"value": "left"}, "angle": {"value": 45}}}, "scale": "x", "title": "", "type": "x"}, {"scale": "y", "title": "place", "type": "y"}], "data": [{"name": "table", "values": [{"col": "predictions", "idx": "filtered_stochastic", "val": 7.0}, {"col": "round1", "idx": "filtered_stochastic", "val": 5.0}, {"col": "round2", "idx": "filtered_stochastic", "val": 5.9}, {"col": "round3", "idx": "filtered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic", "val": 4.0}, {"col": "round1", "idx": "unfiltered_stochastic", "val": 5.0}, {"col": "round2", "idx": "unfiltered_stochastic", "val": 5.9}, {"col": "round3", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch", "val": 7.0}, {"col": "round1", "idx": "filtered_batch", "val": 5.0}, {"col": "round2", "idx": "filtered_batch", "val": 5.9}, {"col": "round3", "idx": "filtered_batch", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch", "val": 4.0}, {"col": "round1", "idx": "unfiltered_batch", "val": 5.0}, {"col": "round2", "idx": "unfiltered_batch", "val": 5.9}, {"col": "round3", "idx": "unfiltered_batch", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_final", "val": 7.0}, {"col": "round1", "idx": "filtered_stochastic_final", "val": 5.0}, {"col": "round2", "idx": "filtered_stochastic_final", "val": 5.9}, {"col": "round3", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_final", "val": 4.0}, {"col": "round1", "idx": "unfiltered_stochastic_final", "val": 5.0}, {"col": "round2", "idx": "unfiltered_stochastic_final", "val": 5.9}, {"col": "round3", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_final", "val": 7.0}, {"col": "round1", "idx": "filtered_batch_final", "val": 5.0}, {"col": "round2", "idx": "filtered_batch_final", "val": 5.9}, {"col": "round3", "idx": "filtered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_final", "val": 4.0}, {"col": "round1", "idx": "unfiltered_batch_final", "val": 5.0}, {"col": "round2", "idx": "unfiltered_batch_final", "val": 5.9}, {"col": "round3", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_power", "val": 3.0}, {"col": "round1", "idx": "filtered_stochastic_power", "val": 5.0}, {"col": "round2", "idx": "filtered_stochastic_power", "val": 5.9}, {"col": "round3", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_power", "val": 2.0}, {"col": "round1", "idx": "unfiltered_stochastic_power", "val": 5.0}, {"col": "round2", "idx": "unfiltered_stochastic_power", "val": 5.9}, {"col": "round3", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_power", "val": 3.0}, {"col": "round1", "idx": "filtered_batch_power", "val": 5.0}, {"col": "round2", "idx": "filtered_batch_power", "val": 5.9}, {"col": "round3", "idx": "filtered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_power", "val": 2.0}, {"col": "round1", "idx": "unfiltered_batch_power", "val": 5.0}, {"col": "round2", "idx": "unfiltered_batch_power", "val": 5.9}, {"col": "round3", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_fina_power", "val": 3.0}, {"col": "round1", "idx": "filtered_stochastic_fina_power", "val": 5.0}, {"col": "round2", "idx": "filtered_stochastic_fina_power", "val": 5.9}, {"col": "round3", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochasticl_final_power", "val": 2.0}, {"col": "round1", "idx": "unfiltered_stochasticl_final_power", "val": 5.0}, {"col": "round2", "idx": "unfiltered_stochasticl_final_power", "val": 5.9}, {"col": "round3", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_final ...
#          chart({el: "#vis4eb9402e04ae40129602eaae8c162583"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# dash
# <div id="vise33e4229d34845c1a1bb37c196268227"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"labels": {"align": {"value": "left"}, "angle": {"value": 45}}}, "scale": "x", "title": "", "type": "x"}, {"scale": "y", "title": "place", "type": "y"}], "data": [{"name": "table", "values": [{"col": "predictions", "idx": "filtered_stochastic", "val": 16.0}, {"col": "round1", "idx": "filtered_stochastic", "val": 2.0}, {"col": "round2", "idx": "filtered_stochastic", "val": 6.9}, {"col": "round3", "idx": "filtered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic", "val": 15.0}, {"col": "round1", "idx": "unfiltered_stochastic", "val": 2.0}, {"col": "round2", "idx": "unfiltered_stochastic", "val": 6.9}, {"col": "round3", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch", "val": 16.0}, {"col": "round1", "idx": "filtered_batch", "val": 2.0}, {"col": "round2", "idx": "filtered_batch", "val": 6.9}, {"col": "round3", "idx": "filtered_batch", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch", "val": 15.0}, {"col": "round1", "idx": "unfiltered_batch", "val": 2.0}, {"col": "round2", "idx": "unfiltered_batch", "val": 6.9}, {"col": "round3", "idx": "unfiltered_batch", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_final", "val": 16.0}, {"col": "round1", "idx": "filtered_stochastic_final", "val": 2.0}, {"col": "round2", "idx": "filtered_stochastic_final", "val": 6.9}, {"col": "round3", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_final", "val": 15.0}, {"col": "round1", "idx": "unfiltered_stochastic_final", "val": 2.0}, {"col": "round2", "idx": "unfiltered_stochastic_final", "val": 6.9}, {"col": "round3", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_final", "val": 16.0}, {"col": "round1", "idx": "filtered_batch_final", "val": 2.0}, {"col": "round2", "idx": "filtered_batch_final", "val": 6.9}, {"col": "round3", "idx": "filtered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_final", "val": 15.0}, {"col": "round1", "idx": "unfiltered_batch_final", "val": 2.0}, {"col": "round2", "idx": "unfiltered_batch_final", "val": 6.9}, {"col": "round3", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_power", "val": 9.0}, {"col": "round1", "idx": "filtered_stochastic_power", "val": 2.0}, {"col": "round2", "idx": "filtered_stochastic_power", "val": 6.9}, {"col": "round3", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_power", "val": 6.0}, {"col": "round1", "idx": "unfiltered_stochastic_power", "val": 2.0}, {"col": "round2", "idx": "unfiltered_stochastic_power", "val": 6.9}, {"col": "round3", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_power", "val": 9.0}, {"col": "round1", "idx": "filtered_batch_power", "val": 2.0}, {"col": "round2", "idx": "filtered_batch_power", "val": 6.9}, {"col": "round3", "idx": "filtered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_power", "val": 6.0}, {"col": "round1", "idx": "unfiltered_batch_power", "val": 2.0}, {"col": "round2", "idx": "unfiltered_batch_power", "val": 6.9}, {"col": "round3", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_fina_power", "val": 9.0}, {"col": "round1", "idx": "filtered_stochastic_fina_power", "val": 2.0}, {"col": "round2", "idx": "filtered_stochastic_fina_power", "val": 6.9}, {"col": "round3", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochasticl_final_power", "val": 6.0}, {"col": "round1", "idx": "unfiltered_stochasticl_final_power", "val": 2.0}, {"col": "round2", "idx": "unfiltered_stochasticl_final_power", "val": 6.9}, {"col": "round3", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_bat ...
#          chart({el: "#vise33e4229d34845c1a1bb37c196268227"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# pinky
# <div id="vis5bdad6247b7841f681ac951b4a5d311d"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"labels": {"align": {"value": "left"}, "angle": {"value": 45}}}, "scale": "x", "title": "", "type": "x"}, {"scale": "y", "title": "place", "type": "y"}], "data": [{"name": "table", "values": [{"col": "predictions", "idx": "filtered_stochastic", "val": 33.0}, {"col": "round1", "idx": "filtered_stochastic", "val": 20.0}, {"col": "round2", "idx": "filtered_stochastic", "val": 7.9}, {"col": "round3", "idx": "filtered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic", "val": 37.0}, {"col": "round1", "idx": "unfiltered_stochastic", "val": 20.0}, {"col": "round2", "idx": "unfiltered_stochastic", "val": 7.9}, {"col": "round3", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch", "val": 33.0}, {"col": "round1", "idx": "filtered_batch", "val": 20.0}, {"col": "round2", "idx": "filtered_batch", "val": 7.9}, {"col": "round3", "idx": "filtered_batch", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch", "val": 37.0}, {"col": "round1", "idx": "unfiltered_batch", "val": 20.0}, {"col": "round2", "idx": "unfiltered_batch", "val": 7.9}, {"col": "round3", "idx": "unfiltered_batch", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_final", "val": 33.0}, {"col": "round1", "idx": "filtered_stochastic_final", "val": 20.0}, {"col": "round2", "idx": "filtered_stochastic_final", "val": 7.9}, {"col": "round3", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_final", "val": 37.0}, {"col": "round1", "idx": "unfiltered_stochastic_final", "val": 20.0}, {"col": "round2", "idx": "unfiltered_stochastic_final", "val": 7.9}, {"col": "round3", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_final", "val": 33.0}, {"col": "round1", "idx": "filtered_batch_final", "val": 20.0}, {"col": "round2", "idx": "filtered_batch_final", "val": 7.9}, {"col": "round3", "idx": "filtered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_final", "val": 37.0}, {"col": "round1", "idx": "unfiltered_batch_final", "val": 20.0}, {"col": "round2", "idx": "unfiltered_batch_final", "val": 7.9}, {"col": "round3", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_power", "val": 18.0}, {"col": "round1", "idx": "filtered_stochastic_power", "val": 20.0}, {"col": "round2", "idx": "filtered_stochastic_power", "val": 7.9}, {"col": "round3", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_power", "val": 24.0}, {"col": "round1", "idx": "unfiltered_stochastic_power", "val": 20.0}, {"col": "round2", "idx": "unfiltered_stochastic_power", "val": 7.9}, {"col": "round3", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_power", "val": 18.0}, {"col": "round1", "idx": "filtered_batch_power", "val": 20.0}, {"col": "round2", "idx": "filtered_batch_power", "val": 7.9}, {"col": "round3", "idx": "filtered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_power", "val": 24.0}, {"col": "round1", "idx": "unfiltered_batch_power", "val": 20.0}, {"col": "round2", "idx": "unfiltered_batch_power", "val": 7.9}, {"col": "round3", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_fina_power", "val": 18.0}, {"col": "round1", "idx": "filtered_stochastic_fina_power", "val": 20.0}, {"col": "round2", "idx": "filtered_stochastic_fina_power", "val": 7.9}, {"col": "round3", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochasticl_final_power", "val": 24.0}, {"col": "round1", "idx": "unfiltered_stochasticl_final_power", "val": 20.0}, {"col": "round2", "idx": "unfiltered_stochasticl_final_power", "val": 7.9}, {"col": "round3", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "predictions",  ...
#          chart({el: "#vis5bdad6247b7841f681ac951b4a5d311d"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# antenna
# <div id="vis1795a2b0dfe0440db6cb9dd90454d126"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"labels": {"align": {"value": "left"}, "angle": {"value": 45}}}, "scale": "x", "title": "", "type": "x"}, {"scale": "y", "title": "place", "type": "y"}], "data": [{"name": "table", "values": [{"col": "predictions", "idx": "filtered_stochastic", "val": 27.0}, {"col": "round1", "idx": "filtered_stochastic", "val": 7.0}, {"col": "round2", "idx": "filtered_stochastic", "val": 8.9}, {"col": "round3", "idx": "filtered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic", "val": 20.0}, {"col": "round1", "idx": "unfiltered_stochastic", "val": 7.0}, {"col": "round2", "idx": "unfiltered_stochastic", "val": 8.9}, {"col": "round3", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch", "val": 27.0}, {"col": "round1", "idx": "filtered_batch", "val": 7.0}, {"col": "round2", "idx": "filtered_batch", "val": 8.9}, {"col": "round3", "idx": "filtered_batch", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch", "val": 20.0}, {"col": "round1", "idx": "unfiltered_batch", "val": 7.0}, {"col": "round2", "idx": "unfiltered_batch", "val": 8.9}, {"col": "round3", "idx": "unfiltered_batch", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_final", "val": 27.0}, {"col": "round1", "idx": "filtered_stochastic_final", "val": 7.0}, {"col": "round2", "idx": "filtered_stochastic_final", "val": 8.9}, {"col": "round3", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_final", "val": 20.0}, {"col": "round1", "idx": "unfiltered_stochastic_final", "val": 7.0}, {"col": "round2", "idx": "unfiltered_stochastic_final", "val": 8.9}, {"col": "round3", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_final", "val": 27.0}, {"col": "round1", "idx": "filtered_batch_final", "val": 7.0}, {"col": "round2", "idx": "filtered_batch_final", "val": 8.9}, {"col": "round3", "idx": "filtered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_final", "val": 20.0}, {"col": "round1", "idx": "unfiltered_batch_final", "val": 7.0}, {"col": "round2", "idx": "unfiltered_batch_final", "val": 8.9}, {"col": "round3", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_power", "val": 20.0}, {"col": "round1", "idx": "filtered_stochastic_power", "val": 7.0}, {"col": "round2", "idx": "filtered_stochastic_power", "val": 8.9}, {"col": "round3", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_power", "val": 28.0}, {"col": "round1", "idx": "unfiltered_stochastic_power", "val": 7.0}, {"col": "round2", "idx": "unfiltered_stochastic_power", "val": 8.9}, {"col": "round3", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_power", "val": 20.0}, {"col": "round1", "idx": "filtered_batch_power", "val": 7.0}, {"col": "round2", "idx": "filtered_batch_power", "val": 8.9}, {"col": "round3", "idx": "filtered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_power", "val": 28.0}, {"col": "round1", "idx": "unfiltered_batch_power", "val": 7.0}, {"col": "round2", "idx": "unfiltered_batch_power", "val": 8.9}, {"col": "round3", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_fina_power", "val": 20.0}, {"col": "round1", "idx": "filtered_stochastic_fina_power", "val": 7.0}, {"col": "round2", "idx": "filtered_stochastic_fina_power", "val": 8.9}, {"col": "round3", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochasticl_final_power", "val": 28.0}, {"col": "round1", "idx": "unfiltered_stochasticl_final_power", "val": 7.0}, {"col": "round2", "idx": "unfiltered_stochasticl_final_power", "val": 8.9}, {"col": "round3", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "predictions", "idx": "filter ...
#          chart({el: "#vis1795a2b0dfe0440db6cb9dd90454d126"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# ziggy
# <div id="visd4d31c3f13b14e179f37356c617c5f69"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"labels": {"align": {"value": "left"}, "angle": {"value": 45}}}, "scale": "x", "title": "", "type": "x"}, {"scale": "y", "title": "place", "type": "y"}], "data": [{"name": "table", "values": [{"col": "predictions", "idx": "filtered_stochastic", "val": 18.0}, {"col": "round1", "idx": "filtered_stochastic", "val": 9.0}, {"col": "round2", "idx": "filtered_stochastic", "val": 9.9}, {"col": "round3", "idx": "filtered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic", "val": 16.0}, {"col": "round1", "idx": "unfiltered_stochastic", "val": 9.0}, {"col": "round2", "idx": "unfiltered_stochastic", "val": 9.9}, {"col": "round3", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch", "val": 18.0}, {"col": "round1", "idx": "filtered_batch", "val": 9.0}, {"col": "round2", "idx": "filtered_batch", "val": 9.9}, {"col": "round3", "idx": "filtered_batch", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch", "val": 16.0}, {"col": "round1", "idx": "unfiltered_batch", "val": 9.0}, {"col": "round2", "idx": "unfiltered_batch", "val": 9.9}, {"col": "round3", "idx": "unfiltered_batch", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_final", "val": 18.0}, {"col": "round1", "idx": "filtered_stochastic_final", "val": 9.0}, {"col": "round2", "idx": "filtered_stochastic_final", "val": 9.9}, {"col": "round3", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_final", "val": 16.0}, {"col": "round1", "idx": "unfiltered_stochastic_final", "val": 9.0}, {"col": "round2", "idx": "unfiltered_stochastic_final", "val": 9.9}, {"col": "round3", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_final", "val": 18.0}, {"col": "round1", "idx": "filtered_batch_final", "val": 9.0}, {"col": "round2", "idx": "filtered_batch_final", "val": 9.9}, {"col": "round3", "idx": "filtered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_final", "val": 16.0}, {"col": "round1", "idx": "unfiltered_batch_final", "val": 9.0}, {"col": "round2", "idx": "unfiltered_batch_final", "val": 9.9}, {"col": "round3", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_power", "val": 32.0}, {"col": "round1", "idx": "filtered_stochastic_power", "val": 9.0}, {"col": "round2", "idx": "filtered_stochastic_power", "val": 9.9}, {"col": "round3", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_power", "val": 25.0}, {"col": "round1", "idx": "unfiltered_stochastic_power", "val": 9.0}, {"col": "round2", "idx": "unfiltered_stochastic_power", "val": 9.9}, {"col": "round3", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_power", "val": 32.0}, {"col": "round1", "idx": "filtered_batch_power", "val": 9.0}, {"col": "round2", "idx": "filtered_batch_power", "val": 9.9}, {"col": "round3", "idx": "filtered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_power", "val": 25.0}, {"col": "round1", "idx": "unfiltered_batch_power", "val": 9.0}, {"col": "round2", "idx": "unfiltered_batch_power", "val": 9.9}, {"col": "round3", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_fina_power", "val": 32.0}, {"col": "round1", "idx": "filtered_stochastic_fina_power", "val": 9.0}, {"col": "round2", "idx": "filtered_stochastic_fina_power", "val": 9.9}, {"col": "round3", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochasticl_final_power", "val": 25.0}, {"col": "round1", "idx": "unfiltered_stochasticl_final_power", "val": 9.0}, {"col": "round2", "idx": "unfiltered_stochasticl_final_power", "val": 9.9}, {"col": "round3", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "predictions", "idx": "filter ...
#          chart({el: "#visd4d31c3f13b14e179f37356c617c5f69"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# buddy
# <div id="vis612375f2b969466bac2d901e89dc5aa7"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
# ...
#          chart({el: "#visdc6da8db28334474b0833817caeeb9b3"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# chai
# <div id="visf73e2ffdfc4b46ce9cba48ee9f8b7f51"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"labels": {"align": {"value": "left"}, "angle": {"value": 45}}}, "scale": "x", "title": "", "type": "x"}, {"scale": "y", "title": "place", "type": "y"}], "data": [{"name": "table", "values": [{"col": "predictions", "idx": "filtered_stochastic", "val": 39.0}, {"col": "round1", "idx": "filtered_stochastic", "val": 0.0}, {"col": "round2", "idx": "filtered_stochastic", "val": 0.0}, {"col": "round3", "idx": "filtered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic", "val": 41.0}, {"col": "round1", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "round2", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "round3", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch", "val": 39.0}, {"col": "round1", "idx": "filtered_batch", "val": 0.0}, {"col": "round2", "idx": "filtered_batch", "val": 0.0}, {"col": "round3", "idx": "filtered_batch", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch", "val": 41.0}, {"col": "round1", "idx": "unfiltered_batch", "val": 0.0}, {"col": "round2", "idx": "unfiltered_batch", "val": 0.0}, {"col": "round3", "idx": "unfiltered_batch", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_final", "val": 39.0}, {"col": "round1", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "round2", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "round3", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_final", "val": 41.0}, {"col": "round1", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "round2", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "round3", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_final", "val": 39.0}, {"col": "round1", "idx": "filtered_batch_final", "val": 0.0}, {"col": "round2", "idx": "filtered_batch_final", "val": 0.0}, {"col": "round3", "idx": "filtered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_final", "val": 41.0}, {"col": "round1", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "round2", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "round3", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_power", "val": 48.0}, {"col": "round1", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "round2", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "round3", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_power", "val": 55.0}, {"col": "round1", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "round2", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "round3", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_power", "val": 48.0}, {"col": "round1", "idx": "filtered_batch_power", "val": 0.0}, {"col": "round2", "idx": "filtered_batch_power", "val": 0.0}, {"col": "round3", "idx": "filtered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_power", "val": 55.0}, {"col": "round1", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "round2", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "round3", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_fina_power", "val": 48.0}, {"col": "round1", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "round2", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "round3", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochasticl_final_power", "val": 55.0}, {"col": "round1", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "round2", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "round3", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "predictions", "idx": "filter ...
#          chart({el: "#visf73e2ffdfc4b46ce9cba48ee9f8b7f51"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# buddha
# <div id="vis2bdde8de36f146ceb5119be25ca9c64c"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"labels": {"align": {"value": "left"}, "angle": {"value": 45}}}, "scale": "x", "title": "", "type": "x"}, {"scale": "y", "title": "place", "type": "y"}], "data": [{"name": "table", "values": [{"col": "predictions", "idx": "filtered_stochastic", "val": 38.0}, {"col": "round1", "idx": "filtered_stochastic", "val": 0.0}, {"col": "round2", "idx": "filtered_stochastic", "val": 0.0}, {"col": "round3", "idx": "filtered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic", "val": 39.0}, {"col": "round1", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "round2", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "round3", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch", "val": 38.0}, {"col": "round1", "idx": "filtered_batch", "val": 0.0}, {"col": "round2", "idx": "filtered_batch", "val": 0.0}, {"col": "round3", "idx": "filtered_batch", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch", "val": 39.0}, {"col": "round1", "idx": "unfiltered_batch", "val": 0.0}, {"col": "round2", "idx": "unfiltered_batch", "val": 0.0}, {"col": "round3", "idx": "unfiltered_batch", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_final", "val": 38.0}, {"col": "round1", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "round2", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "round3", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_final", "val": 39.0}, {"col": "round1", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "round2", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "round3", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_final", "val": 38.0}, {"col": "round1", "idx": "filtered_batch_final", "val": 0.0}, {"col": "round2", "idx": "filtered_batch_final", "val": 0.0}, {"col": "round3", "idx": "filtered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_final", "val": 39.0}, {"col": "round1", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "round2", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "round3", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_power", "val": 55.0}, {"col": "round1", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "round2", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "round3", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_power", "val": 62.0}, {"col": "round1", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "round2", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "round3", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_power", "val": 55.0}, {"col": "round1", "idx": "filtered_batch_power", "val": 0.0}, {"col": "round2", "idx": "filtered_batch_power", "val": 0.0}, {"col": "round3", "idx": "filtered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_power", "val": 62.0}, {"col": "round1", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "round2", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "round3", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_fina_power", "val": 55.0}, {"col": "round1", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "round2", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "round3", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochasticl_final_power", "val": 62.0}, {"col": "round1", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "round2", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "round3", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "predictions", "idx": "filter ...
#          chart({el: "#vis2bdde8de36f146ceb5119be25ca9c64c"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# honey
# <div id="visc5623ef9fe7246059279a58ed651bccd"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"labels": {"align": {"value": "left"}, "angle": {"value": 45}}}, "scale": "x", "title": "", "type": "x"}, {"scale": "y", "title": "place", "type": "y"}], "data": [{"name": "table", "values": [{"col": "predictions", "idx": "filtered_stochastic", "val": 5.0}, {"col": "round1", "idx": "filtered_stochastic", "val": 0.0}, {"col": "round2", "idx": "filtered_stochastic", "val": 0.0}, {"col": "round3", "idx": "filtered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic", "val": 8.0}, {"col": "round1", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "round2", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "round3", "idx": "unfiltered_stochastic", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch", "val": 5.0}, {"col": "round1", "idx": "filtered_batch", "val": 0.0}, {"col": "round2", "idx": "filtered_batch", "val": 0.0}, {"col": "round3", "idx": "filtered_batch", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch", "val": 8.0}, {"col": "round1", "idx": "unfiltered_batch", "val": 0.0}, {"col": "round2", "idx": "unfiltered_batch", "val": 0.0}, {"col": "round3", "idx": "unfiltered_batch", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_final", "val": 5.0}, {"col": "round1", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "round2", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "round3", "idx": "filtered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_final", "val": 8.0}, {"col": "round1", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "round2", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "round3", "idx": "unfiltered_stochastic_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_final", "val": 5.0}, {"col": "round1", "idx": "filtered_batch_final", "val": 0.0}, {"col": "round2", "idx": "filtered_batch_final", "val": 0.0}, {"col": "round3", "idx": "filtered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_final", "val": 8.0}, {"col": "round1", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "round2", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "round3", "idx": "unfiltered_batch_final", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_power", "val": 10.0}, {"col": "round1", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "round2", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "round3", "idx": "filtered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochastic_power", "val": 13.0}, {"col": "round1", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "round2", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "round3", "idx": "unfiltered_stochastic_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch_power", "val": 10.0}, {"col": "round1", "idx": "filtered_batch_power", "val": 0.0}, {"col": "round2", "idx": "filtered_batch_power", "val": 0.0}, {"col": "round3", "idx": "filtered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_batch_power", "val": 13.0}, {"col": "round1", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "round2", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "round3", "idx": "unfiltered_batch_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_stochastic_fina_power", "val": 10.0}, {"col": "round1", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "round2", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "round3", "idx": "filtered_stochastic_fina_power", "val": 0.0}, {"col": "predictions", "idx": "unfiltered_stochasticl_final_power", "val": 13.0}, {"col": "round1", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "round2", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "round3", "idx": "unfiltered_stochasticl_final_power", "val": 0.0}, {"col": "predictions", "idx": "filtered_batch ...
#          chart({el: "#visc5623ef9fe7246059279a58ed651bccd"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
